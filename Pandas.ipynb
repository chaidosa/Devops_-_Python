# %% [markdown]
# <a href="https://colab.research.google.com/github/priteshvermaa/Devops_-_Python/blob/master/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**What is pandas-python? Introduction and Installation**
#
# Pandas is python module that makes data science easy and effective
#
# Weather dataset
#
# Questions?
#
# 1. What was the maximum temperature in new york in the month of january?
#
# 2. On which days did it rains?
#
# 3. What was the average speed of wind during the month.

# %%
import pandas as pd
df = pd.read_csv('nyc_weather.csv')
df
# Out:
#           EST  Temperature  DewPoint  ...  CloudCover    Events  WindDirDegrees
# 0    1/1/2016           38        23  ...           5       NaN             281
# 1    1/2/2016           36        18  ...           3       NaN             275
# 2    1/3/2016           40        21  ...           1       NaN             277
# 3    1/4/2016           25         9  ...           3       NaN             345
# 4    1/5/2016           20        -3  ...           0       NaN             333
# 5    1/6/2016           33         4  ...           0       NaN             259
# 6    1/7/2016           39        11  ...           3       NaN             293
# 7    1/8/2016           39        29  ...           8       NaN              79
# 8    1/9/2016           44        38  ...           8      Rain              76
# 9   1/10/2016           50        46  ...           7      Rain             109
# 10  1/11/2016           33         8  ...           1       NaN             289
# ...

# %%
# get the maximum temperature
df['Temperature'].max()
# Out:
# 50

# %%
# to know which day it rans
df['EST'][df['Events'] == 'Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
# average wind speed
df['WindSpeedMPH'].mean()
# Out:
# 6.892857142857143

# %% [markdown]
# # For installation localy
# **pip3 install pandas**

# %% [markdown]
# #**Introduction to Pandas Dataframe**
#
# Dataframe is a main object in pandas. it used to represent data with rows and columns.
#
# Data frame is a datastructure represent the data in tabular or excel spread sheet like data

# %%
import pandas as pd

df = pd.read_csv('weather_data.csv')
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
#list of tuples -> another way to form dataframe

weather_data = [('1/1/2017', 32, 6, 'Rain'),
                ('1/2/2017', 35, 7, 'Sunny'),
                ('1/3/2017', 28, 2, 'Snow'),
                ('1/4/2017', 24, 7, 'Snow')]

df = pd.DataFrame(weather_data, columns=['day', 'temp', 'windSpeed', 'dataLike'])
df
# Out:
#         day  temp  windSpeed dataLike
# 0  1/1/2017    32          6     Rain
# 1  1/2/2017    35          7    Sunny
# 2  1/3/2017    28          2     Snow
# 3  1/4/2017    24          7     Snow

# %%
#get dimensions of the table
df = pd.read_csv('weather_data.csv')
df.shape
# Out:
# (6, 4)

# %%
# if you want to see initial some rows then use head command (default 5 rows are returned)
df.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %%
df.tail() #bottom rows
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df[2:5]
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow
# 4  1/5/2017           32          4  Rain

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df.temperature
# Out:
# 0    32
# 1    35
# 2    28
# 3    24
# 4    32
# 5    31
# Name: temperature, dtype: int64

# %%
df[['day', 'event']]
# Out:
#         day  event
# 0  1/1/2017   Rain
# 1  1/2/2017  Sunny
# 2  1/3/2017   Snow
# 3  1/4/2017   Snow
# 4  1/5/2017   Rain
# 5  1/6/2017  Sunny

# %%
df['temperature']
# Out:
# 0    32
# 1    35
# 2    28
# 3    24
# 4    32
# 5    31
# Name: temperature, dtype: int64

# %%
df['temperature'].max()
# Out:
# 35

# %%
df['temperature'].describe()
# Out:
# count     6.000000
# mean     30.333333
# std       3.829708
# min      24.000000
# 25%      28.750000
# 50%      31.500000
# 75%      32.000000
# max      35.000000
# Name: temperature, dtype: float64

# %%
# select rows which has max temp
df[df.temperature == df.temperature.max()]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
#select only day column which has max temp
df['day'][df['temperature'] == df.temperature.max()]
# Out:
# 1    1/2/2017
# Name: day, dtype: object

# %%
df.day[df.temperature == df.temperature.max()]
# Out:
# 1    1/2/2017
# Name: day, dtype: object

# %%
import pandas as pd

df = pd.read_csv('weather_data.csv')
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df = pd.read_excel('weather_data.xlsx')
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.to_csv('new_csv') # it stores index number along with data.

# %%
df.to_csv('new_noIndex', index = False) # it doesn't store any indices.

# %%
#write data frame to Excel
df.to_excel('new.xlsx', sheet_name = 'weather_data')

# %%
# Group By
import pandas as pd
df = pd.read_csv('weather_data_cities.csv')
df #weather by cities
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
g =df.groupby('city')
g

# %%
for city, city_df in g:
  print(city)
  print(city_df)
# Out:
# mumbai
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# new york
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# paris
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
# to get spcific group
g.get_group('new york')
# Out:
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny

# %%
#Find maximum temperature in each of the cities
print(g.temperature.max())
# Out:
# city
# mumbai      92
# new york    36
# paris       54
# Name: temperature, dtype: int64

# %%
# maximum temperature, windespeed
g.max()
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
#average for each of the cities
print(g.mean())
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
print(g.describe())
# Out:
#          temperature                         ... windspeed
#                count   mean       std   min  ...       25%   50%    75%   max
# city                                         ...
# mumbai           4.0  88.50  3.109126  85.0  ...      5.00   8.5  12.75  15.0
# new york         4.0  32.25  3.304038  28.0  ...      6.75   7.0   8.25  12.0
# paris            4.0  47.75  5.315073  42.0  ...      9.50  11.5  14.75  20.0
#
# [3 rows x 16 columns]

# %%
#COncatenate DataFrame

# %%
import pandas as pd
india_weather = pd.DataFrame({
    "city": ["mumbai", "delhi", "banglore"],
    "temperature": [32, 45, 30],
    "humidity": [80, 60, 78]
})

print(india_weather)
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
us_weather = pd.DataFrame({
    "city": ["new york", "chicago", "orlando"],
    "temperature": [21, 14, 35],
    "humidity": [68, 65, 75]
})

print(us_weather)
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
#concatenate two dataframes

df = pd.concat([india_weather, us_weather])
print(df)
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
# if you want continous index
df = pd.concat([india_weather, us_weather], ignore_index= True)
print(df)
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        68
# 4   chicago           14        65
# 5   orlando           35        75

# %%
df = pd.concat([india_weather, us_weather], axis = 1) #concatenation row-wise
print(df)
# Out:
#        city  temperature  humidity      city  temperature  humidity
# 0    mumbai           32        80  new york           21        68
# 1     delhi           45        60   chicago           14        65
# 2  banglore           30        78   orlando           35        75

# %%
df = pd.concat([india_weather, us_weather], axis = 0) #concatenating col-wise
print(df)
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
temperature_df = pd.DataFrame({
    "city": ["mumbai", "delhi", "banglore", "hyderabad"],
    "temperature": [32, 45, 30, 40]
})

print(temperature_df)
# Out:
#         city  temperature
# 0     mumbai           32
# 1      delhi           45
# 2   banglore           30
# 3  hyderabad           40

# %%
humidity_df = pd.DataFrame({
    "city": ["delhi", "mumbai", "banglore"],
    "humidity": [68, 65, 75]
})

print(humidity_df)
# Out:
#        city  humidity
# 0     delhi        68
# 1    mumbai        65
# 2  banglore        75

# %%
#merge two dataframes with out explicitly mentioning index
df = pd.merge(temperature_df, humidity_df, on = 'city')
print(df)
# Out:
#        city  temperature  humidity
# 0    mumbai           32        65
# 1     delhi           45        68
# 2  banglore           30        75

# %%
#Outer-Join
df = pd.merge(temperature_df, humidity_df, on = 'city', how = 'outer')
df
# Out:
#         city  temperature  humidity
# 0     mumbai           32      65.0
# 1      delhi           45      68.0
# 2   banglore           30      75.0
# 3  hyderabad           40       NaN

# %% [markdown]
# #**Numerical Indexing (.loc vs .iloc)**

# %%
s = pd.DataFrame([1,2,3, 4,5,6,7,8,9,19], index = [49, 48, 47, 46, 45, 1,2,3,4,5])
s
# Out:
#      0
# 49   1
# 48   2
# 47   3
# 46   4
# 45   5
# 1    6
# 2    7
# 3    8
# 4    9
# 5   19

# %%
s.loc[46] #using the index you specified
# Out:
# 0    4
# Name: 46, dtype: int64

# %%
s.iloc[3] #using the indices by row number
# Out:
# 0    4
# Name: 46, dtype: int64

# %%
s.loc[45]
# Out:
# 0    5
# Name: 45, dtype: int64

# %%
s.iloc[45] #we don't have that many rows so this will give you an error
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-42-e6eb416fdede> in <module>()
# ----> 1 s.iloc[45] #we don't have that many rows so this will give you an error
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
#    1568             return self.obj._ixs(key, axis=axis)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
# ...

# %%
s.loc[:2] #all the values til it finds 2
# Out:
#     0
# 49  1
# 48  2
# 47  3
# 46  4
# 45  5
# 1   6
# 2   7

# %%
s.iloc[:2] # row-wise starting from 0 till 2(exclusive)
# Out:
#     0
# 49  1
# 48  2
