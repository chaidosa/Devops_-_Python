# %%
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

#generating a gaussian random variable
x = stats.norm.rvs(size = 1000);
sns.set_style('whitegrid')
sns.kdeplot(np.array(x), bw_method = 0.5)
plt.show()

# %%
stats.kstest(x, 'norm')
# Out:
# KstestResult(statistic=0.02397440082312996, pvalue=0.604766217402894)

# %%
y = np.random.uniform(0, 1, 10000)
sns.kdeplot(np.array(y), bw_method = 0.1)
plt.show()

# %%
stats.kstest(y, 'norm')
# Out:
# KstestResult(statistic=0.5000098986400086, pvalue=0.0)
